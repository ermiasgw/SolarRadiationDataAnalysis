# %% [markdown]
# lets analyze the box plot for each data

# %%
import pandas as pd

region_1 = pd.read_pickle("no_negative_1.pk1")

region_2 = pd.read_pickle("no_negative_2.pk1")

region_3 = pd.read_pickle("no_negative_3.pk1")

# %%
import matplotlib.pyplot as plt

region_1.boxplot()

plt.show()

# %% [markdown]
# there is an outlier in column DHI so clean it

# %%
import sys
sys.path.append('../scripts/')

# %%
from filter_outliers import remove_outliers

no_outlier_1 = remove_outliers(region_1, "DHI")

no_outlier_1.boxplot()

plt.show()

# %%
region_2.boxplot()

plt.show()

# %% [markdown]
# here there exist an outlier on column GHI and DHI.

# %%
no_outlier_2 = remove_outliers(region_2, "GHI")
no_outlier_2 = remove_outliers(no_outlier_2, "DHI")


no_outlier_2.boxplot()

plt.show()

# %%
region_3.boxplot()

plt.show()

# %% [markdown]
# here there exist outlier in DHI

# %%
no_outlier_3 = remove_outliers(region_3, "DHI")

no_outlier_3.boxplot()

plt.show()

# %% [markdown]
# now removing outliers is finished there are outliers in other parts but for time lets ignore them.

# %%
no_outlier_1.to_pickle("no_outlier_1.pk1")
no_outlier_2.to_pickle("no_outlier_2.pk1")
no_outlier_3.to_pickle("no_outlier_3.pk1")
