# %%
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1NtM7JjBIIK-aE_WMpX4w7yYqKF-H-Kvg&export=download")

df.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("https://drive.google.com/uc?id=1NtM7JjBIIK-aE_WMpX4w7yYqKF-H-Kvg&export=download")
#       5 df.describe()
#
# ...

# %%
df.head()

# %% [markdown]
# lets start analyzing
#
# our objective is to analyze Solar Radiation Measurement Data to identify which region is suitable for solar installation.
#
# we have 3 regions benin-malanville, sierraleone-bumbuna, togo-dapang_qc.
#
# we have data of mesurements that is measured every second.
#
# lets import those data and see the data. it may take too much time downloading the data

# %%
import pandas as pd

region_1 = pd.read_csv("https://drive.google.com/uc?id=1CHYBTpYTR4aUiqg0dLpt03LLEp0Y7bwx")
region_1.head()
region_2 = pd.read_csv("https://drive.google.com/uc?id=1NtM7JjBIIK-aE_WMpX4w7yYqKF-H-Kvg")
region_2.head()
region_3 = pd.read_csv("https://drive.google.com/uc?id=1EJKhVFemVxkNLtxO6AEVf56Njd41iPQK")
region_3.head()

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# we have got the data now we need to clean the data
#
# lets see that how good is the data quality.
#
# first lets check if there are any empty values and clean it.

# %%
# %run "./Download_data.ipynb"

region_1.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      240.559452     167.187516     115.358961     236.589496
# std       331.131327     261.710501     158.691074     326.894859
# min       -12.900000      -7.800000     -12.600000       0.000000
# 25%        -2.000000      -0.500000      -2.100000       0.000000
# 50%         1.800000      -0.100000       1.600000       4.500000
# 75%       483.400000     314.200000     216.300000     463.700000
# max      1413.000000     952.300000     759.200000    1342.300000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.883576      28.179683      54.487969       2.121113
# std       316.536515       5.924297      28.073069       1.603466
# min         0.000000      11.000000       2.100000       0.000000
# ...
