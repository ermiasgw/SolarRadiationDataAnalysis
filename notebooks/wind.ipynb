# %% [markdown]
# wind analysis

# %%
import pandas as pd

region_1 = pd.read_pickle("no_outlier_1.pk1")

region_2 = pd.read_pickle("no_outlier_2.pk1")

region_3 = pd.read_pickle("no_outlier_3.pk1")

# %% [markdown]
# for region 1

# %%
region_1.dtypes
# Out:
# Timestamp         object
# GHI              float64
# DNI              float64
# DHI              float64
# ModA             float64
# ModB             float64
# Tamb             float64
# RH               float64
# WS               float64
# WSgust           float64
# WSstdev          float64
# WD               float64
# WDstdev          float64
# BP                 int64
# Cleaning           int64
# Precipitation    float64
# TModA            float64
# TModB            float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Plot Wind Speed (WS)
axs[0, 0].plot(region_1.index, region_1['WS'], marker='o', linestyle='-', color='b')
axs[0, 0].set_title('Wind Speed (WS)')
axs[0, 0].set_xlabel('Time')
axs[0, 0].set_ylabel('WS (m/s)')

# Plot Wind Gust (WSgust)
axs[0, 1].plot(region_1.index, region_1['WSgust'], marker='o', linestyle='-', color='r')
axs[0, 1].set_title('Wind Gust (WSgust)')
axs[0, 1].set_xlabel('Time')
axs[0, 1].set_ylabel('WSgust (m/s)')

# Plot Wind Speed Standard Deviation (WSstdev)
axs[1, 0].plot(region_1.index, region_1['WSstdev'], marker='o', linestyle='-', color='g')
axs[1, 0].set_title('Wind Speed Std Deviation (WSstdev)')
axs[1, 0].set_xlabel('Time')
axs[1, 0].set_ylabel('WSstdev (m/s)')

# Plot Wind Direction (WD)
axs[1, 1].plot(region_1.index, region_1['WD'], marker='o', linestyle='-', color='purple')
axs[1, 1].set_title('Wind Direction (WD)')
axs[1, 1].set_xlabel('Time')
axs[1, 1].set_ylabel('WD (degrees)')

# Adjust layout
plt.tight_layout()

# Show plots
plt.show()
